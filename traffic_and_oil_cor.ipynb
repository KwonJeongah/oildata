# %%
import pandas as pd
from pandas import DataFrame

# %%
#한국 유가 정보 불러오기
koreaoil = pd.read_csv("st_data_oilKorea.tsv", delimiter = '\t')

# %%
#한국 유가 정보를 엑셀로 저장
writer = pd.ExcelWriter('oilKorea.xlsx')
koreaoil.to_excel(writer,'Sheet1')
writer.save()

# %%
#한국 유가 정보를 월별 평균(oil_month_avg, 종가기준)하여 불러오기
oil_month_mean = pd.read_excel("oil_month_mean.xlsx")

# %%
oil_month_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
# date    48 non-null object
# mean    48 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 848.0+ bytes

# %%
oil_month_mean.head()
# Out:
#       date         mean
# 0  2015-01  1504.200000
# 1  2015-02  1440.320000
# 2  2015-03  1508.968889
# 3  2015-04  1507.509000
# 4  2015-05  1543.337000

# %%
oil_month_mean = oil_month_mean.set_index("date")

# %%
oil_month_mean.head()
# Out:
#                 mean
# date
# 2015-01  1504.200000
# 2015-02  1440.320000
# 2015-03  1508.968889
# 2015-04  1507.509000
# 2015-05  1543.337000

# %%
month_2015 = DataFrame(index=("1종","2종","3종","4종","5종","6종","총교통량"))
month_2015
# Out:
# Empty DataFrame
# Columns: []
# Index: [1종, 2종, 3종, 4종, 5종, 6종, 총교통량]

# %%
month_2015 = DataFrame(index=("1종","2종","3종","4종","5종","6종","총교통량"))
month_2015

data = pd.read_csv("201501.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201501'] = pd.Series(data.mean())

data = pd.read_csv("201502.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201502'] = pd.Series(data.mean())

data = pd.read_csv("201503.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201503'] = pd.Series(data.mean())

data = pd.read_csv("201504.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201504'] = pd.Series(data.mean())

data = pd.read_csv("201505.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201505'] = pd.Series(data.mean())

data = pd.read_csv("201506.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201606'] = pd.Series(data.mean())

data = pd.read_csv("201507.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201507'] = pd.Series(data.mean())

data = pd.read_csv("201508.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201508'] = pd.Series(data.mean())

data = pd.read_csv("201509.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201509'] = pd.Series(data.mean())

data = pd.read_csv("201510.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201510'] = pd.Series(data.mean())

data = pd.read_csv("201511.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201511'] = pd.Series(data.mean())

data = pd.read_csv("201512.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2015['201512'] = pd.Series(data.mean())

# %%
month_2015
# Out:
#            201501       201502       201503       201504       201505  \
# 1종    3786.686650  4016.208540  4036.508045  4179.156838  4433.565487
# 2종     163.596359   175.802369   183.729112   180.003476   169.729273
# 3종     222.688406   210.533630   222.868639   243.947408   232.162803
# 4종     119.022139   126.033963   126.228813   130.221846   125.830765
# 5종     169.314173   166.161891   180.195967   183.848604   174.285044
# 6종     237.413666   229.138837   241.411191   245.320147   262.953609
# 총교통량  4698.721392  4923.879230  4990.941768  5162.498319  5398.526981
#
#            201606       201507       201508       201509       201510  \
# 1종    4100.688892  4233.890999  4580.810563  4531.548204  4442.137825
# 2종     281.963710   188.249062   195.376834   171.813540   182.114668
# 3종     352.277183   242.933161   242.640831   224.785450   258.244596
# 4종     190.465892   168.978559   131.604482   129.590109   143.530084
# ...

# %%
month_2015.to_excel("month_2015.xlsx")

# %%
month_2016 = DataFrame(index=("1종","2종","3종","4종","5종","6종","총교통량"))
month_2016.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1종, 2종, 3종, 4종, 5종]

# %%
month_2016 = DataFrame(index=("1종","2종","3종","4종","5종","6종","총교통량"))

data = pd.read_csv("201601.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201601'] = pd.Series(data.mean())

data = pd.read_csv("201602.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201602'] = pd.Series(data.mean())

data = pd.read_csv("201603.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201603'] = pd.Series(data.mean())

data = pd.read_csv("201604.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201604'] = pd.Series(data.mean())

data = pd.read_csv("201605.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201605'] = pd.Series(data.mean())

data = pd.read_csv("201606.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201606'] = pd.Series(data.mean())

data = pd.read_csv("201607.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201607'] = pd.Series(data.mean())

data = pd.read_csv("201608.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201608'] = pd.Series(data.mean())

data = pd.read_csv("201609.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201609'] = pd.Series(data.mean())

data = pd.read_csv("201610.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201610'] = pd.Series(data.mean())

data = pd.read_csv("201611.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201611'] = pd.Series(data.mean())

data = pd.read_csv("201612.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2016['201612'] = pd.Series(data.mean())

# %%
month_2016
# Out:
#            201601       201602       201603       201604       201605  \
# 1종    3868.751678  4113.558292  4106.484653  4396.144483  4471.842573
# 2종     150.659097   144.184407   168.173913   186.818068   198.557113
# 3종     203.764705   197.449044   224.593415   248.591897   261.707305
# 4종     119.435211   113.811271   136.037589   159.697954   151.542277
# 5종     169.045681   160.637494   208.052301   223.612132   213.796260
# 6종     242.320809   230.465399   241.019725   258.347558   253.759243
# 총교통량  4753.977182  4960.105906  5084.361596  5473.212091  5551.204771
#
#            201606       201607       201608       201609       201610  \
# 1종    4411.222798  4337.122571  4566.018814  4455.104499  4475.972556
# 2종     176.308072   159.617165   159.022916   152.302266   163.263236
# 3종     233.095297   215.900093   212.346792   212.714490   240.932438
# 4종     168.157881   130.514918   130.764610   126.595740   134.681407
# ...

# %%
month_2016.to_excel("month_2016.xlsx")

# %%
#2017
#빈 dataframe 생성
month_2017 = DataFrame(index=("1종","2종","3종","4종","5종","6종","총교통량"))
month_2017.head()

#데이터 불러와서 평균내기
data = pd.read_csv("201701.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201701'] = pd.Series(data.mean())

data = pd.read_csv("201702.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201702'] = pd.Series(data.mean())

data = pd.read_csv("201703.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201703'] = pd.Series(data.mean())

data = pd.read_csv("201704.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201704'] = pd.Series(data.mean())

data = pd.read_csv("201705.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201705'] = pd.Series(data.mean())

data = pd.read_csv("201706.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201706'] = pd.Series(data.mean())

data = pd.read_csv("201707.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201707'] = pd.Series(data.mean())

data = pd.read_csv("201708.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201708'] = pd.Series(data.mean())

data = pd.read_csv("201709.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201709'] = pd.Series(data.mean())

data = pd.read_csv("201710.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201710'] = pd.Series(data.mean())

data = pd.read_csv("201711.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201711'] = pd.Series(data.mean())

data = pd.read_csv("201712.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2017['201712'] = pd.Series(data.mean())

#엑셀로 저장
month_2017.to_excel("month_2017.xlsx")

# %%
#2018
#빈 dataframe 생성
month_2018 = DataFrame(index=("1종","2종","3종","4종","5종","6종","총교통량"))
month_2018.head()

#데이터 불러와서 평균내기
data = pd.read_csv("201801.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201801'] = pd.Series(data.mean())

data = pd.read_csv("201802.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201802'] = pd.Series(data.mean())

data = pd.read_csv("201803.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201803'] = pd.Series(data.mean())

data = pd.read_csv("201804.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201804'] = pd.Series(data.mean())

data = pd.read_csv("201805.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201805'] = pd.Series(data.mean())

data = pd.read_csv("201806.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201806'] = pd.Series(data.mean())

data = pd.read_csv("201807.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201807'] = pd.Series(data.mean())

data = pd.read_csv("201808.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201808'] = pd.Series(data.mean())

data = pd.read_csv("201809.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201809'] = pd.Series(data.mean())

data = pd.read_csv("201810.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201810'] = pd.Series(data.mean())

data = pd.read_csv("201811.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201811'] = pd.Series(data.mean())

data = pd.read_csv("201812.txt", sep = '|', header=None)
data.columns = ["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드",
                      "고속도로운영기관구분코드","영업형태구분코드","1종","2종","3종","4종","5종","6종","총교통량","NULL"]
data = data.drop(["집계일자","영업소코드","입출구구분코드","TCS하이패스구분코드"
                                ,"고속도로운영기관구분코드","영업형태구분코드","NULL"], axis=1)

month_2018['201812'] = pd.Series(data.mean())

#엑셀로 저장
month_2018.to_excel("month_2018.xlsx")

# %%
import numpy as np

# %%
month_2015 = month_2015.T
month_2016 = month_2016.T
month_2017 = month_2017.T
month_2018 = month_2018.T

# %%
month_traffic = pd.concat([month_2015, month_2016, month_2017, month_2018])

# %%
month_traffic.head()
# Out:
#                  1종          2종          3종          4종          5종  \
# 201501  3786.686650  163.596359  222.688406  119.022139  169.314173
# 201502  4016.208540  175.802369  210.533630  126.033963  166.161891
# 201503  4036.508045  183.729112  222.868639  126.228813  180.195967
# 201504  4179.156838  180.003476  243.947408  130.221846  183.848604
# 201505  4433.565487  169.729273  232.162803  125.830765  174.285044
#
#                 6종         총교통량
# 201501  237.413666  4698.721392
# 201502  229.138837  4923.879230
# 201503  241.411191  4990.941768
# 201504  245.320147  5162.498319
# 201505  262.953609  5398.526981

# %%
month_traffic.to_excel("month_traffic.xlsx")

# %%
oil_month_mean.head()
# Out:
#                mean
# date
# 201501  1504.200000
# 201502  1440.320000
# 201503  1508.968889
# 201504  1507.509000
# 201505  1543.337000

# %%
oil_month_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 201501 to 201812
# Data columns (total 1 columns):
# mean    48 non-null float64
# dtypes: float64(1)
# memory usage: 768.0 bytes

# %%
oil_rate = pd.read_excel("자동차_등록자료.xlsx")

# %%
oil_rate.head()
# Out:
#      date     전체 차량   승용 휘발유  승합 휘발유  화물 휘발유  특수 휘발유   휘발유 합         비율
# 0  201501  20217803  3776262    1760    5218      34  3783274  0.187126
# 1  201502  20276476  3780281    1762    5229      34  3787306  0.186783
# 2  201503  20339450  9635134    5189    9404      50  9649777  0.474436
# 3  201504  20411896  9655829    5165    9403      50  9670447  0.473765
# 4  201505  20474184  9669611    5127    9404      50  9684192  0.472995

# %%
#OIL_traffic은 월별 전체 차량의 합
oil_traffic = pd.read_excel("oil_traffic.xlsx")

# %%
oil_traffic.head()
# Out:
#      date         1종        2종        3종       4종        5종        6종  \
# 2  201503  182373470   8301065  10069428  5703144   8141434  10907199
# 3  201504  182767066   7872092  10668552  5694992   8040251  10728586
# 4  201505  198499594   7599119  10394393  5633695   7803090  11772959
# 5  201506  178535793  12276136  15337444  8292504  12206046  13789052
# 6  201507  188386980   8376142  10809311  7518701  10762928  13082702
#
#         총교통량         mean
# 2  225495740  1508.968889
# 3  225771539  1507.509000
# 4  241702850  1543.337000
# 5  240436975  1580.046000
# 6  238936764  1575.770909

# %%
result_data = pd.merge(oil_traffic, oil_rate, on = 'date')

# %%
result_data.head()
# Out:
#      date         1종        2종        3종       4종        5종        6종  \
# 0  201503  182373470   8301065  10069428  5703144   8141434  10907199
# 1  201504  182767066   7872092  10668552  5694992   8040251  10728586
# 2  201505  198499594   7599119  10394393  5633695   7803090  11772959
# 3  201506  178535793  12276136  15337444  8292504  12206046  13789052
# 4  201507  188386980   8376142  10809311  7518701  10762928  13082702
#
#         총교통량         mean     전체 차량   승용 휘발유  승합 휘발유  화물 휘발유  특수 휘발유   휘발유 합   \
# 0  225495740  1508.968889  20339450  9635134    5189    9404      50  9649777
# 1  225771539  1507.509000  20411896  9655829    5165    9403      50  9670447
# 2  241702850  1543.337000  20474184  9669611    5127    9404      50  9684192
# 3  240436975  1580.046000  20548879  9684786    5097    9406      50  9699339
# 4  238936764  1575.770909  20624932  9700688    5059    9398      50  9715195
#
#          비율
# 0  0.474436
# 1  0.473765
# 2  0.472995
# 3  0.472013
# ...

# %%
#1종, 6종 - 승용, 2,3 - 승합, 4 - 화물, 5-특수라 가정, 자동차보유대수로엑셀작업함
result_data.to_excel("oil_traffic2.xlsx")

# %%
result = pd.read_excel("oil_rate_traffic.xlsx")

# %%
result.head()
# Out:
#       date         1종       2종        3종       4종       5종        6종  \
# 0  2015-01  170355459  7359873  10018306  5354568  7617106  10680766
# 1  2015-02  162716689  7122633   8529770  5106266  6732049   9283560
# 2  2015-03  182373470  8301065  10069428  5703144  8141434  10907199
# 3  2015-04  182767066  7872092  10668552  5694992  8040251  10728586
# 4  2015-05  198499594  7599119  10394393  5633695  7803090  11772959
#
#         총교통량         mean     전체 차량      ...       승합 휘발유  화물 휘발유  특수 휘발유  \
# 0  211386078  1504.200000  20217803      ...         1760    5218      34
# 1  199490967  1440.320000  20276476      ...         1762    5229      34
# 2  225495740  1508.968889  20339450      ...         5189    9404      50
# 3  225771539  1507.509000  20411896      ...         5165    9403      50
# 4  241702850  1543.337000  20474184      ...         5127    9404      50
#
#     휘발유 합         비율            승용           승합           화물         특수  \
# ...

# %%
plt.figure(figsize=(7,2))
plt.plot(result['date'], result['전체'])
plt.ylabel('total_traffic')
plt.xlabel('date')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
result = result.drop([0,1],0) #201501,201502는 201503에 비하여 10만대 이상 차이가 나므로 제외

# %%
result.head()
# Out:
#       date         1종        2종        3종       4종        5종        6종  \
# 2  2015-03  182373470   8301065  10069428  5703144   8141434  10907199
# 3  2015-04  182767066   7872092  10668552  5694992   8040251  10728586
# 4  2015-05  198499594   7599119  10394393  5633695   7803090  11772959
# 5  2015-06  178535793  12276136  15337444  8292504  12206046  13789052
# 6  2015-07  198487381   7933158  10488356  7566432  10696904  12229980
#
#         총교통량         mean     전체 차량      ...       승합 휘발유  화물 휘발유  특수 휘발유  \
# 2  225495740  1508.968889  20339450      ...         5189    9404      50
# 3  225771539  1507.509000  20411896      ...         5165    9403      50
# 4  241702850  1543.337000  20474184      ...         5127    9404      50
# 5  240436975  1580.046000  21464224      ...         4758    9620      46
# 6  247402211  1437.008000  21464224      ...         4758    9620      46
#
#     휘발유 합         비율            승용           승합           화물         특수  \
# ...

# %%
result = result.rename(columns = {'mean': 'oil_mean'})

# %%
plt.scatter( result['oil_mean'], result['승용'])
plt.ylabel('traffic')
plt.xlabel('oil price')
plt.title('passanger car')
plt.show()

# %%
plt.scatter( result['oil_mean'], result['승합'])
plt.ylabel('traffic')
plt.xlabel('oil price')
plt.title('van')
plt.show()

# %%
plt.scatter( result['oil_mean'], result['화물'])
plt.ylabel('traffic')
plt.xlabel('oil price')
plt.title('cargo')
plt.show()

# %%
plt.scatter( result['oil_mean'], result['특수'])
plt.ylabel('traffic')
plt.xlabel('oil price')
plt.title('special car')
plt.show()

# %%
plt.scatter( result['oil_mean'], result['총교통량'])
plt.ylabel('total traffic')
plt.xlabel('oil price')
plt.title('total traffic and oil price')
plt.show()

# %%
result['oil_mean'].corr(result['승용'])
# Out:
# 0.16992739613448002

# %%
result['oil_mean'].corr(result['승합'])
# Out:
# -0.1384029135711172

# %%
result['oil_mean'].corr(result['화물'])
# Out:
# 0.2283135792682081

# %%
result['oil_mean'].corr(result['특수'])
# Out:
# 0.31364882800772964

# %%
result['oil_mean'].corr(result['총교통량'])
# Out:
# 0.21072397251854705
